# %% [markdown]
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# Дарса, привет!
#
# Меня зовут Олег Михеев, и я буду проверять твой проект. Предлагаю общаться на "ты", но если тебе будет некомфортно, обязательно сообщи, и мы перейдем на "вы". Моя главная цель - не указать на твои ошибки, а поделиться опытом и подготовить тебя к работе аналитиком. Увидев у тебя ошибку, я постараюсь указать на её наличие и дам возможность найти и самостоятельно исправить её.
#
# В проверке проекта я буду использовать разные цвета для обозначения комментариев. Например:
#
# <br/>
#
# <div class="alert alert-success">
# <h3> Комментарий ревьюера ✔️<a class="tocSkip"> </h3>
#
# Так выделены удачные решения, на которые можно опираться в будущем.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h3> Комментарий ревьюера ⚠️<a class="tocSkip"> </h3>
#
# Когда решение на отдельном шаге станет лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h3> Комментарий ревьюера ❌<a class="tocSkip"></h3>
#
#  А так выделены решения, которые необходимо доработать, чтобы я мог принять проект.
# </div>
#
#
# Если вносишь изменения в проект, указывай, пожалуйста, это в своих комментариях. Будет удобно, если обозначишь их заметным цветом. Например, вот так:
#
# <div class="alert alert-block alert-info">
#
# <h3> Комментарий студента  <a class="tocSkip"></h3>
#
# Можешь кликнуть сюда два раза и скопировать код комментария. Также если что-то непонятно или остались вопросы по ревью, обязательно пиши.
#
# </div>
#
# Пожалуйста, не удаляй и не перемещай мои комментарии, чтобы не произошло путаницы, и я мог быстрее проверить проект.
# <br/>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по ревью**
#
# Хорошая работа. Ты умело пользуешься кодом для решения поставленных задач. И уже строишь наглядные графики
#
# А твои выводы понятны и отражают результаты расчетов.
#
# **Чтобы я мог принять проект, твоего внимания требуют следующие моменты**:
#
# * Первые гистограммы
# * Пропуски
# * Нетипичные значения
# * Объём потерянных данных на каждом шаге
# * Гистограммы
# * Финальный вывод
#
# **Успехов! Жду проект на повторное ревью!**

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по ревью v2**
#
# Дарса, спасибо, что учёл все рекомендации и замечания.
#
# Очень качественно выполненный проект! Мне было приятно с тобой работать 🤝
#
# Видно, что ты последовательно и вдумчиво подходишь к анализу.
#
# А проект написан аккуратно, поэтому его легко воспринимать.
#
# Продолжай в том же духе и станешь крутым специалистом.
#
# **Успехов в дальнейшем обучении!**

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Вам нужно научиться определять рыночную стоимость объектов недвижимости. Для этого проведите исследовательский анализ данных и установите параметры, влияющие на цену объектов. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта и других объектов — эти данные автоматически получены из геосервисов. Количество парков и водоёмов также заполняется без участия пользователя.

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера ✔️<a class="tocSkip"> </h3>
#
#  Стоило бы расписать цели и задачи своими словами. Этот навык пригодится тебе в финальном спринте.
# </div>

# %% [markdown]
# ### <span style="color:red">Цель: научиться определять рыночную стоимость объектов недвижимости.</span>
# ### <span style="color:red">Задача: провести исследовательский анализ данных и установить параметры, влияющие на цену объектов.</span>

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера v2 ✔️<a class="tocSkip"> </h3>
#
#  Отлично, теперь проект будет проще воспринимать.
# </div>

# %% [markdown]
# ## <span style="color:blue">Шаг 1.Откройте файл с данными и изучите общую информацию</span>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# назначаем переменную для датасета

data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %%
# выводим общую информацию

display(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
display(data.head())
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
# строим гистограммы для всех числовых столбцов

data.hist(bins=50, figsize=(15, 20))
plt.show()

# %% [markdown]
# ### <span style="color:brown">Комментарии к шагу 1:</span>
# #### <span style="color:brown">1) total_images. График слишком шумный: распределение не является ни нормальным, ни пуассоновским.</span>
# #### <span style="color:brown">2) last_price. Слишком крупный масштаб привел гистограмму к столбчатому виду. Комментировать что-то конкретное тяжело.</span>
# #### <span style="color:brown">3) total_area. Основная квадратура общей площади находится в пределах до 200 кв.м.</span>
# #### <span style="color:brown">4) rooms. У столбца rooms имеются нулевые значения. Не бывает квартир с нулем комнат. Стоит обратить на это внимание.</span>
# #### <span style="color:brown">5) ceiling_height. last_price. Слишком крупный масштаб привел гистограмму к столбчатому виду. Комментировать что-то конкретное тяжело.</span>
# #### <span style="color:brown">6) floors_total. Этажность зданий выше 30-ти уже является крайней редкостью.</span>
# #### <span style="color:brown">7) living_area. Основная квадратура жилой площади находится в пределах до 100 кв.м.</span>
# #### <span style="color:brown">8) floor. Имеет распределение Пуассона. Чем ниже этаж, тем больше квартир.</span>
# #### <span style="color:brown">9) kitchen_area. Кухни больше 25 кв.м. являются редкостью.</span>
# #### <span style="color:brown">10) balcony. Квартиры, у которых больше двух балконов, являются редкостью.</span>
# #### <span style="color:brown">11) airports_nearest. Неоднородность данных. Возможно, это связано с тем, что авиаперелеты не являются услугой ежедневного потребления и этот критерий не играет главной роли при покупке квартиры.</span>
# #### <span style="color:brown">12) cityCenters_nearest. Несколько пиков разной величины указывают на несколько населенных пунктов в датасете, что в свою очередь подразумевает и несколько городских центров с различными расстояниями до них.</span>
# #### <span style="color:brown">13) parks_around3000. Тенденция такова: чем меньше близлежащих парков, тем больше квартир.</span>
# #### <span style="color:brown">14) parks_nearest. На пике популярности находится расстояние 500 м.</span>
# #### <span style="color:brown">15) ponds_around3000. Тенденция такова: чем меньше близлежащих бассейнов, тем больше квартир.</span>
# #### <span style="color:brown">16) ponds_nearest. Имеет нормальное распределение. На пике популярности находится расстояние 500 м.</span>
# #### <span style="color:brown">17) days_exposition. Имеет распределение Пуассона. Быстрых объявлений больше длительных.</span>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h3> Комментарий ревьюера ❌<a class="tocSkip"></h3>
#
# Данные готовы к работе, а гистограммы выведены.
#
# Лучше разделять блоки загрузки библиотек и данных в разные ячейки. Если захочешь добавить дополнительную библиотеку, то датасет не будет загружаться заново, а вся предшествующая работа не обнулится.
#
# Чтобы избавиться от информации о сабплотах перед графиками, можно добавить строку plt.show(). Но прежде нужно загрузить библиотеку matplotlib
#
# Прокомментируй, пожалуйста, гистограммы. Можно тезисно, потому что углубленное изучение всё равно будет дальше. Рекомендую взять за привычку всегда описывать графики.
#
# </div>

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера v2 ✔️<a class="tocSkip"> </h3>
#
#  Отлично, распределения и первые проблемы в данных обозначены.
# </div>

# %% [markdown]
# ## <span style="color:blue">Шаг 2.Выполните предобработку данных</span>

# %% [markdown]
# ### <span style="color:orange">Подшаг 2.1. Заполнение пропусков и замена типа данных</span>

# %% [markdown]
# ### <span style="color:green">Задача 2.1.1</span>

# %% [markdown]
# #### Если в столбцах balcony, parks_around3000, ponds_around3000 стоят пропуски, то, скорее всего, этих объектов там нет. Поэтому заменяем все пропуски на ноль. А так как не бывает 1,5 балкона или 2,8 парка, заменим тип данных float64 на int64.

# %%
data['balcony'] = data['balcony'].fillna(0).astype('int')
data['parks_around3000'] = data['parks_around3000'].fillna(0).astype('int')
data['ponds_around3000'] = data['ponds_around3000'].fillna(0).astype('int')

# выводим данные для проверки
display(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               23699 non-null  int64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# ### <span style="color:green">Задача 2.1.2</span>

# %% [markdown]
# #### Столбец is_apartment. Там, где пропуски, видимо, квартира не являлась аппартаментами и ее не заполнили. Значит, все пустые значения заменяем значением False. Следовательно, у нас столбец должен содержать два значения True и False. Формат столбца поменяется с object на bool.

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)
display(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               23699 non-null  int64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# #### <span style="color:brown">Комментарий к подшагу 2.1: для остальных данных нет коррелирующих переменных в остальном датасете, из  которых можно было бы вывести значения для пустых ячеек. Исключение: столбец living_area. Жилая площадь коррелирует с количеством жилых комнат. Однако, этот столбец требует предварительного исследования, что относится к шагу 4. Поэтому, замена пропусков будет перенесена на этот шаг.</span>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h3> Комментарий ревьюера ❌<a class="tocSkip"></h3>
#
# Столбцы апартаментов, балконов, парков и водоёмов рядом обработаны верно. Но прокомментируй и другие столбцы с пропусками, пожалуйста. Если решил не заполнять пропуски, то всё равно напиши почему.
#
# Чтобы изменить тип данных в столбце высоты домов, пропуски по столбцу можно удалить, так как их крайне мало, что не сильно повлияет на общую таблицу. Пропуски имеют тип float.
# </div>

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера v2 ✔️<a class="tocSkip"> </h3>
#
#  Отлично, теперь принято решение по всем столбцам
# </div>

# %% [markdown]
# ### <span style="color:orange">Подшаг 2.2. Замена неявных дубликатов.</span>

# %%
display(data['locality_name'].unique())
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %%
data['locality_name'] = (data['locality_name'].str.replace('ё', 'е'))
data['locality_name'] = data['locality_name'].replace(['городской поселок Лесогорский'], 'поселок городского типа Лесогорский', regex=True) 
data['locality_name'] = data['locality_name'].replace(['городской поселок Назия'], 'поселок городского типа Назия', regex=True)    
data['locality_name'] = data['locality_name'].replace(['городской поселок Советский'], 'поселок городского типа Советский', regex=True)   
data['locality_name'] = data['locality_name'].replace(['поселок Мурино'], 'Мурино', regex=True)    
data['locality_name'] = data['locality_name'].replace(['городской поселок Янино-1'], 'поселок городского типа Янино-1', regex=True)    
data['locality_name'] = data['locality_name'].replace(['городской поселок Рощино'], 'поселок городского типа Рощино', regex=True)
data['locality_name'] = data['locality_name'].replace(['поселок Рябово'], 'поселок городского типа Рябово', regex=True)
data['locality_name'] = data['locality_name'].replace(['поселок при железнодорожной станции Вещево'], 'поселок станции Вещево', regex=True)
data['locality_name'] = data['locality_name'].replace(['поселок Лесное'], 'коттеджный поселок Лесное', regex=True)
data['locality_name'] = data['locality_name'].replace(['поселок при железнодорожной станции Приветнинское'], 'поселок станции Приветнинское', regex=True)

display(data['locality_name'].unique())
# Out:
# array(['Санкт-Петербург', 'поселок Шушары',
#        'поселок городского типа Янино-1', 'поселок Парголово', 'Мурино',
#        'Ломоносов', 'Сертолово', 'Петергоф', 'Пушкин', 'деревня Кудрово',
#        'Коммунар', 'Колпино', 'поселок городского типа Красный Бор',
#        'Гатчина', 'деревня Федоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'поселок Металлострой',
#        'поселок городского типа Лебяжье',
#        'поселок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'поселок Аннино',
#        'поселок городского типа Ефимовский', 'поселок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
#        'Красное Село', 'поселок Понтонный', 'Сясьстрой', 'деревня Старая',
# ...

# %% [markdown]
# #### <span style="color:brown">Комментарий к подшагу 2.2: Неявные дубликаты заменены и количество уникальных значений столбца уменьшилось. Пустые значения оставляем как есть, так как эти данные не выводятся из остального датасета.</span>

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера ✔️<a class="tocSkip"> </h3>
#
# Все дубликаты обработаны верно. Здорово, что пишешь промежуточные выводы. Это улучшает читаемость.
#
# Чтобы сэкономить себе время, можно также использовать схожее этому решение:
#
#     df = df.apply(lambda x: x.replace({'поселок':'посёлок', 'городской посёлок': 'посёлок', 'посёлок городского типа': 'посёлок', 'коттеджный посёлок': 'посёлок', 'посёлок при железнодорожной станции': 'посёлок станции'}, regex=True))
#
# </div>

# %% [markdown]
# ## <span style="color:blue">Шаг 3. Добавьте в таблицу новые столбцы</span>

# %%
# добавляем столбец со стоимостью квадратного метра
data['price_square'] = (data['last_price'] / data['total_area']).round(2)

# добавляем столбцы с указанием дня недели, месяца и года
data['weekday'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%d %H:%M').dt.weekday
data['month'] = pd.DatetimeIndex(data['first_day_exposition']).month
data['year'] = pd.DatetimeIndex(data['first_day_exposition']).year

# добавляем столбец с указанием расстояния до центра в километрах
data['km_centre'] = (data['cityCenters_nearest']/1000).round(0)

# добавляем столбец с указанием типа этажа
data['type_floor'] = 'другой'
q_first = (data['floor']  == 1)
q_last = (data['floor'] == data['floors_total'])
data.loc[q_first, 'type_floor'] = 'первый'
data.loc[q_last, 'type_floor'] = 'последний'

display(data.head())
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0         51.0      8         False  ...
# 1             NaN          11.0         18.6      1         False  ...
# 2             NaN           5.0         34.3      4         False  ...
# 3             NaN          14.0          NaN      9         False  ...
# 4            3.03          14.0         32.0     13         False  ...
#
#    parks_nearest  ponds_around3000  ponds_nearest  days_exposition  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h3> Комментарий ревьюера ❌<a class="tocSkip"></h3>
#
# Всё добавлено верно. Но столбец удалённости от центра (km_centre)  необходимо округлить до целых чисел, иначе в одном из заданий не получится построить понятный график.
# </div>

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера v2 ✔️<a class="tocSkip"> </h3>
#
#  👍
# </div>

# %% [markdown]
# ## <span style="color:blue">Шаг 4. Проведите исследовательский анализ данных</span>

# %% [markdown]
# ### <span style="color:orange">Подшаг 4.1. Обработка аномалий и построение гистограмм</span>

# %% [markdown]
# ### <span style="color:green">Задача 4.1.1</span>

# %% [markdown]
# #### В шаге 1 мы обнаружили, что столбец rooms имеет ноль комнат. Это странно. Давайте посмотрим, сколько таких значений:

# %%
display(data['rooms'].value_counts())
# Out:
# 1     8047
# 2     7940
# 3     5814
# 4     1180
# 5      326
# 0      197
# 6      105
# 7       59
# 8       12
# 9        8
# 10       3
# 11       2
# 14       2
# 19       1
# 16       1
# 12       1
# 15       1
# Name: rooms, dtype: int64

# %% [markdown]
# #### <span style="color:brown">Оказалось, что в столбце находится 197 квартир с нулем комнат! У меня гипотеза, что это квартиры-студии. Возможно из-за того, что в студиях кухня совмещена с жилой зоной, а кухня не учитывается в количестве комнат, то пользователи указали 0. Проверим сколько среди нулевых квартир числится студий:</span>

# %%
data_rooms0 = data[(data['rooms'] == 0) & (data['studio'] == True)]
display(len(data_rooms0))
# Out:
# 138

# %% [markdown]
# #### <span style="color:brown">138 квартир из 197 являются таковыми. Это 70%. Так как эти данные заполняются пользователями вручную, то предположу, что таковыми являются все квартиры. Просто не все люди знают, что такое "студия" и могли просто не заполнять этот пункт. Думаю, что можно отнести эти квартиры к 1-комнатным. Тем более, что студии числятся в техдокументах как однокомнатные квартиры.</span>

# %%
# заменяем 0 на 1 в столбце rooms

data['rooms'] = data['rooms'].replace([0], 1, regex=True)
display(data['rooms'].value_counts())
# Out:
# 1     8244
# 2     7940
# 3     5814
# 4     1180
# 5      326
# 6      105
# 7       59
# 8       12
# 9        8
# 10       3
# 11       2
# 14       2
# 16       1
# 19       1
# 12       1
# 15       1
# Name: rooms, dtype: int64

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера ✔️<a class="tocSkip"> </h3>
#
#  Логично! Обработано верно
# </div>

# %% [markdown]
# #### <span style="color:brown">Во избежание статистических выбросов можно аннулировать редкие значения. Судя по данным выше, это все квартиры, у которых количество комнат больше 7.</span>

# %%
# отбираем строки согласно условию:
q_rooms = data['rooms'] > 7

data.loc[q_rooms, 'rooms'] = float('nan')

display(data['rooms'].value_counts())
# Out:
# 1.0    8244
# 2.0    7940
# 3.0    5814
# 4.0    1180
# 5.0     326
# 6.0     105
# 7.0      59
# Name: rooms, dtype: int64

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера ✔️<a class="tocSkip"> </h3>
#
#  Согласен с тобой
# </div>

# %% [markdown]
# ### <span style="color:green">Задача 4.1.2</span>

# %% [markdown]
# #### Общая площадь

# %%
display(data[['total_area',  'living_area',  'kitchen_area', 'rooms', 'studio', 'is_apartment']] \
        .sort_values('total_area').head(10))
# Out:
#        total_area  living_area  kitchen_area  rooms  studio  is_apartment
# 19904        12.0         10.0           NaN    1.0   False         False
# 17961        13.0          NaN           NaN    1.0   False         False
# 19546        13.0          NaN           NaN    1.0   False         False
# 19807        13.0         10.0           NaN    1.0   False         False
# 19558        13.2          NaN           NaN    1.0   False         False
# 19642        14.0         11.0           2.0    1.0   False         False
# 16949        15.0          NaN           NaN    1.0   False         False
# 12040        15.0          NaN           NaN    1.0   False         False
# 8886         15.5         10.0           NaN    1.0    True         False
# 9412         16.0         13.0           NaN    1.0   False         False

# %% [markdown]
# ##### <span style="color:brown">Согласно СНиП, минимальная общая площадь квартиры должна составляет 24 кв.м. Тогда, почему такие низкие значения в столбце? Может быть пользователи поставили запятую не там. Но, если 12,00 - это на самом деле 120,0 тогда и жилая площадь и количество комнат должны быть соответствующе большими. Однако жилая площадь тоже маленькая, а комната всего одна. И так у всех аномально низких значений. Поэтому оставим общие площади как есть.</span>

# %% [markdown]
# ### <span style="color:green">Задача 4.1.3</span>

# %% [markdown]
# #### Жилая площадь

# %%
display(data[['total_area',  'living_area',  'kitchen_area', 'rooms', 'studio', 'is_apartment']] \
        .sort_values('living_area').head(10))
# Out:
#        total_area  living_area  kitchen_area  rooms  studio  is_apartment
# 21758        23.0          2.0           NaN    1.0    True         False
# 13915        52.0          2.0           9.0    2.0   False         False
# 23574       139.0          3.0          16.0    3.0   False         False
# 3242         41.0          3.0          11.0    1.0   False         False
# 17582        22.0          5.0           NaN    1.0    True         False
# 21943        77.6          5.4           9.8    4.0   False         False
# 16431        31.0          6.0          17.0    1.0   False         False
# 19251        33.0          6.5          18.0    1.0   False         False
# 20994        50.6          8.0          31.0    2.0   False         False
# 23208        37.0          8.0          22.0    1.0   False         False

# %% [markdown]
# ##### <span style="color:brown">Жилая площадь не может быть 2 кв.м. Тем более в 2-х комнатной квартире с общей площадью 52 кв.м. Или 3 кв.м. в квартире с общей площадью в 41 кв.м. А вот 20 и 30 кв.м. могут быть и там и там. Может быть, что это тот случай, когда запятая стоит не там. Давайте изменим значения согласно условию: мы увеличиваем значение living_area в 10 раз в том случае, если увеличенное значение будет меньше значения total_area. То есть, если в строчке общая площадь 41 кв.м., а жилая 3,0 кв.м., то вместо 3,0 будет 30,0.</span>

# %%
# отбираем строки согласно условию:
q_liv_are = data['living_area']*10 < data['total_area']

# на пересечении множеств записываем новые значения:
data.loc[q_liv_are, 'living_area'] = data['living_area'] * 10

display(data[['total_area',  'living_area',  'kitchen_area', 'rooms', 'studio', 'is_apartment']] \
        .sort_values('living_area').head(10))
# Out:
#        total_area  living_area  kitchen_area  rooms  studio  is_apartment
# 17582        22.0          5.0           NaN    1.0    True         False
# 16431        31.0          6.0          17.0    1.0   False         False
# 19251        33.0          6.5          18.0    1.0   False         False
# 20994        50.6          8.0          31.0    2.0   False         False
# 23208        37.0          8.0          22.0    1.0   False         False
# 114          21.4          8.3           6.3    1.0   False         False
# 2309         62.4          8.4          41.0    2.0   False         False
# 21505        35.3          8.5          16.1    1.0   False         False
# 17248        33.0          8.9          16.1    1.0   False         False
# 15833        33.0          9.0          14.3    1.0   False         False

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера ✔️<a class="tocSkip"> </h3>
#
#  Верная обработка
# </div>

# %% [markdown]
# #### <span style="color:brown">Низкие значения как-то выровняли. Но, помимо этого, в столбце living_area имеется 1903 пустых значений. Квартира не может быть без жилой зоны. Так как жилая площадь зависит от количества комнат, то поступим следующим образом:
# <span style="color:brown">1) для каждого уникального значения столбца rooms найдем медиану столбца living_area и заполним им пустую ячейку;</span>
#
# <span style="color:brown">2) проверим на наличие пустых значений столбец living_area.</span>

# %%
for t in data['rooms'].unique():
    data.loc[(data['rooms'] == t) & (data['living_area'].isna()), 'living_area'] = \
    data.loc[(data['rooms'] == t), 'living_area'].median()
    
#проверим столбец living_area общим данным

display(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23668 non-null  float64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           23698 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               23699 non-null  int64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера ✔️<a class="tocSkip"> </h3>
#
#  Да, заполнить медианой с учётом комнат - хорошее решение
# </div>

# %% [markdown]
# ### <span style="color:green">Задача 4.1.4</span>

# %% [markdown]
# #### Кухонная площадь

# %%
display(data[['total_area',  'living_area',  'kitchen_area', 'rooms', 'studio', 'is_apartment']] \
        .sort_values('kitchen_area').head(10))
# Out:
#        total_area  living_area  kitchen_area  rooms  studio  is_apartment
# 20217       28.50         19.5           1.3    1.0   False         False
# 9138        23.29         21.0           2.0    1.0   False         False
# 6262        24.00         16.0           2.0    2.0   False         False
# 21419       20.00         14.0           2.0    1.0   False         False
# 19642       14.00         11.0           2.0    1.0   False         False
# 11033       32.00         16.0           2.0    1.0   False         False
# 906         27.00         18.0           2.0    1.0   False         False
# 16367       25.70         22.6           2.0    1.0   False         False
# 17834       34.70         15.5           2.3    1.0   False         False
# 8729        18.40         14.0           2.4    1.0   False         False

# %% [markdown]
# ##### <span style="color:brown">Согласно СНиП, кухня не може быть меньше 5 кв.м. Все эти кухни, по идее, не должны существовать. Однако, если вычесть из общей площади жилую, а разницу раскидать между ванной, коридором и кухней, то примерно это минимальное значение и остается для кухни. Может быть, что по идее одно, а по факту другое. Оставим как есть.</span>

# %% [markdown]
# ### <span style="color:green">Задача 4.1.5</span>

# %% [markdown]
# #### Рассмотрим столбец last_price, то есть цена на момент снятия с публикации. Давайте сравним самые дорогие и дешевые квартиры.

# %%
display(data['last_price'].sort_values().head())
display(data['last_price'].sort_values(ascending=False).head())
# Out:
# 8793      12190.0
# 17456    430000.0
# 14911    430000.0
# 16274    440000.0
# 17676    450000.0
# Name: last_price, dtype: float64
# 12971    763000000.0
# 19540    420000000.0
# 14706    401300000.0
# 1436     330000000.0
# 15651    300000000.0
# Name: last_price, dtype: float64

# %% [markdown]
# #### <span style="color:brown">Cамая низкая стоимость в 12 190,0 руб. вызывает сомнение. Возможно там указана не стоимость квартиры, а стоимость квадратного метра. Давайте рассмотрим эту строку подробнее.</span>

# %%
display(data.loc[8793])
# Out:
# total_images                              7
# last_price                          12190.0
# total_area                            109.0
# first_day_exposition    2019-03-20T00:00:00
# rooms                                   2.0
# ceiling_height                         2.75
# floors_total                           25.0
# living_area                            32.0
# floor                                    25
# is_apartment                          False
# studio                                False
# open_plan                             False
# kitchen_area                           40.5
# balcony                                   0
# locality_name               Санкт-Петербург
# airports_nearest                    36421.0
# cityCenters_nearest                  9176.0
# parks_around3000                          1
# parks_nearest                         805.0
# ponds_around3000                          0
# ponds_nearest                           NaN
# ...

# %% [markdown]
# #### <span style="color:brown">Квартира в 109 кв.м и находится в Питере. Это точно цена за квадрат. Умножим стоимость кв. м. на общую площадь и выведем всю цену:</span>

# %%
data.loc[8793, 'last_price'] = data.loc[8793, 'last_price']*data.loc[8793, 'total_area']
display(data.loc[8793])
# Out:
# total_images                              7
# last_price                        1328710.0
# total_area                            109.0
# first_day_exposition    2019-03-20T00:00:00
# rooms                                   2.0
# ceiling_height                         2.75
# floors_total                           25.0
# living_area                            32.0
# floor                                    25
# is_apartment                          False
# studio                                False
# open_plan                             False
# kitchen_area                           40.5
# balcony                                   0
# locality_name               Санкт-Петербург
# airports_nearest                    36421.0
# cityCenters_nearest                  9176.0
# parks_around3000                          1
# parks_nearest                         805.0
# ponds_around3000                          0
# ponds_nearest                           NaN
# ...

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера ✔️<a class="tocSkip"> </h3>
#
#  Да, небольшая проблема найдена и устранена
# </div>

# %% [markdown]
# #### <span style="color:brown">Вот эта цена уже близка к правде. Далее, остальные дешевые квартиры стоят в районе 430-450 тыс. руб. Тоже не много для целой квартиры. Давайте выведем последние 5 строк и посмотрим на их местоположение:</span>

# %%
display(data.sort_values(by='last_price').head())
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 17456             7    430000.0        30.4  2019-04-22T00:00:00    1.0
# 14911             5    430000.0        54.0  2018-06-26T00:00:00    2.0
# 16274            18    440000.0        40.0  2018-07-10T00:00:00    1.0
# 17676             0    450000.0        36.5  2018-02-01T00:00:00    1.0
# 9581              7    450000.0        43.4  2018-08-31T00:00:00    2.0
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 17456             NaN           2.0         16.0      1         False  ...
# 14911             NaN           3.0         30.5      3         False  ...
# 16274             NaN           5.0         17.6      1         False  ...
# 17676             NaN           5.0         17.3      4         False  ...
# 9581              NaN           5.0         30.3      3         False  ...
#
#        parks_nearest  ponds_around3000  ponds_nearest  days_exposition  \
# ...

# %% [markdown]
# #### <span style="color:brown">Эти квартиры расположены на перифериях Ленинградской области. Исследование по внешним ресурсам показало, что подобные цены уместны для деревень и поселков этой области:</span>

# %% [markdown]
# ![IMG_7958.jpg](attachment:IMG_7958.jpg)

# %% [markdown]
# ![IMG_7959.jpg](attachment:IMG_7959.jpg)

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера ✔️<a class="tocSkip"> </h3>
#
#  Класс 👍 Здорово, что пользуешься внешней информацией
# </div>

# %% [markdown]
# ### <span style="color:green">Задача 4.1.6</span>

# %% [markdown]
# #### Проверим высоту потолков в столбце ceiling_height. Выведем максимальные и минимальные значения.

# %%
display(data['ceiling_height'].sort_values(ascending=False).head())
display(data['ceiling_height'].sort_values().head())
# Out:
# 22869    100.0
# 22336     32.0
# 3148      32.0
# 21377     27.5
# 20478     27.0
# Name: ceiling_height, dtype: float64
# 22590    1.00
# 5712     1.20
# 16934    1.75
# 2572     2.00
# 19329    2.00
# Name: ceiling_height, dtype: float64

# %% [markdown]
# #### <span style="color:brown">Несколько аномально низких потолков и гораздо больше потолков, чья высота превышает 20 метров. Скорее всего, пользователи забыли поставить запятую между целой и десятичной частью числа. Подкорректируем данные.</span>

# %%
# отбираем всё, что больше 20 по высоте
q_height = data['ceiling_height'] >= 20

# по тем индексам, где высота больше 20, записываем обновленные значения
data.loc[q_height, 'ceiling_height'] = data['ceiling_height'] / 10

display(data['ceiling_height'].sort_values(ascending=False).head())
# Out:
# 15061    14.0
# 22309    10.3
# 22869    10.0
# 5863      8.3
# 3474      8.0
# Name: ceiling_height, dtype: float64

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера ✔️<a class="tocSkip"> </h3>
#
#  Обработано верно!
# </div>

# %% [markdown]
# ### Гистограмма 'total_area'

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера ✔️<a class="tocSkip"> </h3>
#
# Рекомендую оформлять проект заголовками и подписями. На данном этапе я не буду обращать внимание на этот момент, но в следующих проектах это уже будет требованием.
#
# Пример кода:
#
#     plt.title('Название заголовка')
#     plt.ylabel('Название оси ординат')
#     plt.xlabel('Название оси абсцисс')
#     plt.show()
#
# Для лучшего понимания работы с гистограммами оставляю ссылку [примеры гистограмм и оформления](https://www.shanelynn.ie/bar-plots-in-python-using-pandas-dataframes/)
#
# Ещё пара ссылок на полезные источники:
#
# * [Как строить красивые графики на Python с Seaborn](https://habr.com/ru/companies/otus/articles/540526/)
#
# * [Seaborn для визуализации данных в Python](https://pythonru.com/biblioteki/seaborn-plot)
#
# Стоит сказать, что для описания типичных диапазонов значений часто применяют график боксплот, который отлично может дополнить следующий за этим комментарием этап. Также этот график позволяет оценить выбросы по каждому из столбцов.

# %%
data['total_area'].hist(bins=100, range = (12, 900), figsize=(12, 8))
#data['total_area'].hist(bins=20, range = (0, 20), figsize=(15, 9))
#data['total_area'].hist(bins=10, range = (150, 350), figsize=(15, 9))
#data['total_area'].hist(bins=10, range = (44, 46), figsize=(15, 9))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### <span style="color:brown">Самая популярная общая площадь - в районе 45 кв.м. Значения меньше 20 и больше 200 являются редкостью. Давайте аннулируем эти непопулярные значения, чтобы они не влияли на среднее и медиану, предварительно проверив соотношение.</span>

# %%
6
y_tot_are = len(data.query('total_area > 200'))
z_tot_are = len(data['total_area'])
w_tot_are = (x_tot_are + y_tot_are) / z_tot_are * 100

display(w_tot_are)
# Out:
# 1.071775180387358

# %% [markdown]
# #### <span style="color:brown">Бритва Оккамы, конечно, немного отупела здесь). Мне визуально легче воспринимать так информацию. Главное, мы выяснили, что отсекаемые значения составляют лишь 1% от общего количества значений.</span>

# %%
q_tot_are = (data['total_area'] < 20) | (data['total_area'] > 200)

data.loc[q_tot_are, 'total_area'] = float('nan')

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h3> Комментарий ревьюера ❌<a class="tocSkip"></h3>
#
# Вывод верный. Но стоит также проверить, какой объём данных соответствует выбранным нетипичным значениям. Сделай это для этого столбца и всех ниже, пожалуйста.
# </div>

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера v2 ✔️<a class="tocSkip"> </h3>
#
#  Супер, теперь точно понятно, что не было утеряно слишком много данных. Если выбросов больше 10 %, то это уже не выбросы, а часть тренда.
# </div>

# %% [markdown]
# ### Гистограмма 'living_area':

# %%
data['living_area'].hist(bins=50, range = (0, 410), figsize=(12, 8))
#data['living_area'].hist(bins=10, range = (100, 109), figsize=(15, 9))
#data['living_area'].hist(bins=10, range = (8, 10), figsize=(15, 9))
#data['living_area'].hist(bins=10, range = (30, 32), figsize=(15, 9))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### <span style="color:brown">Самая популярная жилая площадь - в районе 30 кв.м. Значения меньше 10 и больше 104 являются редкостью. Давайте аннулируем эти непопулярные значения, чтобы они не влияли на среднее и медиану, предварительно проверив их процентное соотношение.</span>

# %%
x_liv_are = len(data.query('living_area < 10'))
y_liv_are = len(data.query('living_area > 104'))
z_liv_are = len(data['living_area'])
w_liv_are = (x_liv_are + y_liv_are) / z_liv_are * 100

display(w_liv_are)
# Out:
# 1.4430988649310097

# %% [markdown]
# #### <span style="color:brown">Всего 1,4%.</span>

# %%
q_liv_are = (data['living_area'] < 10) | (data['living_area'] > 104)

data.loc[q_liv_are, 'living_area'] = float('nan')

# %% [markdown]
# ### Гистограмма 'kitchen_area':

# %%
data['kitchen_area'].hist(bins=50, range = (2, 112), figsize=(15, 9))
#data['kitchen_area'].hist(bins=10, range = (0, 5), figsize=(15, 9))
#data['kitchen_area'].hist(bins=20, range = (31, 50), figsize=(15, 9))
#data['kitchen_area'].hist(bins=50, range = (4, 12), figsize=(15, 9))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### <span style="color:brown">Самая популярная кухонная площадь - в районе 8-10 кв.м. Значения меньше 4 и больше 41 являются редкостью. Давайте аннулируем эти непопулярные значения, чтобы они не влияли на среднее и медиану.</span>

# %%
x_kit_are = len(data.query('kitchen_area < 4'))
y_kit_are = len(data.query('kitchen_area > 41'))
z_kit_are = len(data['kitchen_area'])
w_kit_are = (x_kit_are + y_kit_are) / z_kit_are * 100

display(w_kit_are)
# Out:
# 0.6076205747077935

# %%
q_kit_are = (data['kitchen_area'] < 4) | (data['kitchen_area'] > 41)

data.loc[q_kit_are, 'kitchen_area'] = float('nan')

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера ✔️<a class="tocSkip"> </h3>
#
#  Выводы верные
# </div>

# %% [markdown]
# ### Гистограмма 'last_area':

# %%
data['last_price'].hist(bins=100, range = (430, 160000000), figsize=(15, 9))
#data['last_price'].hist(bins=50, range = (20000000, 40000000), figsize=(15, 9))
#data['last_price'].hist(bins=100, range = (800000, 1000000), figsize=(15, 9))
#data['last_price'].hist(bins=100, range = (3000000, 6000000), figsize=(15, 9))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### <span style="color:brown">Комментарий к графику 'last_price': Самая популярная цена - в районе 3,5-4,5 млн.руб. Значения меньше 850 тыс. и больше 25 млн. являются редкостью. Давайте аннулируем эти непопулярные значения, чтобы они не влияли на среднее и медиану.</span>

# %%
x_price = len(data.query('last_price < 850000'))
y_price = len(data.query('last_price > 25000000'))
z_price = len(data['last_price'])
w_price = (x_price + y_price) / z_price * 100

display(w_price)
# Out:
# 2.48533693404785

# %%
q_price = (data['last_price'] < 850000) | (data['last_price'] > 25000000)

data.loc[q_price, 'last_price'] = float('nan')

# %% [markdown]
# ### Гистограмма 'rooms':

# %%
data['rooms'].hist(bins=7, range = (1, 7), figsize=(12, 8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### <span style="color:brown">Комментарий к графику 'rooms': чем меньше комнат в квартире, тем выше их популярность.</span>

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера ✔️<a class="tocSkip"> </h3>
#
#  Выводы выше верные. А квартир с меньшим количеством комнат просто больше.
# </div>

# %% [markdown]
# ### Гистограмма 'ceiling_height':

# %%
data['ceiling_height'].hist(bins=50, range = (2, 6), figsize=(12, 8))
#data['ceiling_height'].hist(bins=50, range = (2, 2.5), figsize=(15, 9))
#data['ceiling_height'].hist(bins=30, range = (3.5, 3.6), figsize=(15, 9))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### <span style="color:brown">Комментарий к графику 'ceiling_height': Самая распространенная высота 2,5 м. Это и понятно. Это минимальная высота потолка согласно СНиП. Высотой меньше 2,5м и больше 3,5м квартиры встречаются редко. Давайте аннулируем эти непопулярные значения, чтобы они не влияли на среднее и медиану.</span>

# %%
x_height = len(data.query('ceiling_height < 2.5'))
y_height = len(data.query('ceiling_height > 3.5'))
z_height = len(data['ceiling_height'])
w_height = (x_height + y_height) / z_height * 100

display(w_height)
# Out:
# 1.5106122621207645

# %%
q_ceil_heig = (data['ceiling_height'] < 2.5) | (data['ceiling_height'] > 3.5)

data.loc[q_ceil_heig, 'ceiling_height'] = float('nan')

# %% [markdown]
# ### Гистограмма 'type_floor':

# %%
data['type_floor'].hist(figsize=(12, 8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### <span style="color:brown">Комментарий к графику 'type_floor': Первый и последний этажи встречаются почти одинаковое количество раз. Столбец "другой" самый большой потому что в нем все этажи, кроме первого и последнего.</span>

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера ✔️<a class="tocSkip"> </h3>
#
#  Выводы выше верные
# </div>

# %% [markdown]
# ### Гистограмма 'floors_total':

# %%
data['floors_total'].hist(bins=30, range = (1, 30), figsize=(12, 8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### <span style="color:brown">Комментарий к графику 'floors_total': На первом месте пятиэтажки, на втором девятиэтажки. Однако есть нюанс. Квартиры в пятиэтажных домах продают чаще всего потому что это самая распространенная этажность среди домов. Согласно градостроительному кодексу, если застройщик строит больше 5 этажей, то он должен установить в доме лифт и мусоропровод. Поэтому в целях экономии, застройщики останавливаются на 5-ти этажах. Что касается 9-ти этажек, то ситуация такая же. Если строится больше 9-ти этажей, то нужно дополнительно устроить незадымляемые лестничные клетки и системы противодымной защиты. Поэтому выше 9-ти этажей не строились по экономическим соображениям. Следовательно, 5 и 9 этажные дома лидируют, просто потому что их много. Также можно аннулировать редкие значения: меньше 2 и больше 27.</span>

# %%
x_floors = len(data.query('floors_total < 2'))
y_floors = len(data.query('floors_total > 27'))
z_floors = len(data['floors_total'])
w_floors = (x_floors + y_floors) / z_floors * 100

display(w_floors)
# Out:
# 0.33334739862441454

# %%
q_floors = (data['floors_total'] < 2) | (data['floors_total'] > 27)

data.loc[q_floors, 'floors_total'] = float('nan')

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера ✔️<a class="tocSkip"> </h3>
#
#  Хорошее объяснение причин застроек! С выводом согласен.
# </div>

# %% [markdown]
# ### Гистограмма 'cityCenters_nearest':

# %%
data['cityCenters_nearest'].hist(bins=100, range = (180, 66000), figsize=(12, 8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### <span style="color:brown">Комментарий к графику 'cityCenters_nearest': Гистограмма показывает несколько пиков: большой, средний и несколько малых. Сначала я подумал, это связано с тем, что в датасете несколько городов и для каждого центра города свое расстояние в зависимости от его крупности. Однако позже я заметил, что расстояние до центра заполняется автоматически и привязывается к центру Санк-Петербурга.</span>
# #### <span style="color:brown">Самое популярные расстояния до центра: 15 км и 12,5 км.</span>
# #### <span style="color:brown">Проверим, можно ли отсечь все, что выше 35 км и меньше 1 км, если можно.</span>

# %%
x_centre = len(data.query('cityCenters_nearest < 1000'))
y_centre = len(data.query('cityCenters_nearest > 35000'))
z_centre = len(data['cityCenters_nearest'])
w_centre = (x_centre + y_centre) / z_centre * 100

display(w_centre)
# Out:
# 2.156209122747795

# %%
q_centre = (data['cityCenters_nearest'] < 1000) | (data['cityCenters_nearest'] > 35000)

data.loc[q_centre, 'cityCenters_nearest'] = float('nan')

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h3> Комментарий ревьюера ❌<a class="tocSkip"></h3>
#
# Опиши типичные значения, пожалуйста.
# </div>

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера v2 ✔️<a class="tocSkip"> </h3>
#
#  Супер, график описан.
# </div>

# %% [markdown]
# ### Гистограмма 'parks_nearest':

# %%
data['parks_nearest'].hist(bins=100, range = (1, 3190), figsize=(12, 8))
#data['parks_nearest'].hist(bins=10, range = (1, 100), figsize=(15, 9))
#data['parks_nearest'].hist(bins=100, range = (1, 3190), figsize=(15, 9))
#data['parks_nearest'].hist(bins=20, range = (430, 449), figsize=(15, 9))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### <span style="color:brown">Комментарий к графику 'parks_nearest': Самая популярная дистанция до парка - это 440 м. Наверное, потому что это комфортное расстояние для пешей прогулки для среднего человека. Больше 1000 м и меньше 10 м уже редкость. Можно их отсечь.</span>

# %%
x_park = len(data.query('parks_nearest < 10'))
y_park = len(data.query('parks_nearest > 1000'))
z_park = len(data['parks_nearest'])
w_park = (x_park + y_park) / z_park * 100

display(w_park)
# Out:
# 1.6161019452297567

# %%
q_park = (data['parks_nearest'] < 10) | (data['parks_nearest'] > 1000)

data.loc[q_park, 'parks_nearest'] = float('nan')

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера ✔️<a class="tocSkip"> </h3>
#
#  Верно!
# </div>

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера v2 ✔️<a class="tocSkip"> </h3>
#
#  Отлично, по всем столбцам удалён незначительный объём данных. Можем идти дальше.
# </div>

# %% [markdown]
# ### <span style="color:orange">Подшаг 4.2. Скорость продажи квартир.</span>

# %% [markdown]
# #### Выводим гистограмму и общие данные

# %%
data['days_exposition'].hist(bins=100, range = (1, 1580), figsize=(12, 8))

display(data['days_exposition'].describe())
# Out:
# count    20518.000000
# mean       180.888634
# std        219.727988
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# #### <span style="color:brown">Комментарий к графику 'days_exposition': Теперь я хочу отсечь редкие значения и снова вывести гистограмму и общие данные. Согласно гистограмме, это все значения больше 1000 дней.</span>

# %%
#проверям процент значений больше 1000 от общего числа значений

x_expo = len(data.query('parks_nearest < 10'))
y_expo = len(data.query('parks_nearest > 1000'))
z_expo = len(data['parks_nearest'])
w_expo = (x_expo + y_expo) / z_expo * 100

display(w_expo)
# Out:
# 0.0

# %%
# отбираем всё, что больше 1000:
q_expo = data['days_exposition'] > 1000

data.loc[q_expo, 'days_exposition'] = float('nan')

data['days_exposition'].hist(bins=100, range = (1, 1580), figsize=(12, 8))

# выводим общие данные

display(data['days_exposition'].describe())
# Out:
# count    20242.000000
# mean       167.411866
# std        187.599458
# min          1.000000
# 25%         44.000000
# 50%         93.000000
# 75%        222.000000
# max       1000.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# #### <span style="color:brown">Комментарий к графику 'days_exposition': Средняя продолжительность продажи квартиры снизилась со 180 дней до 167. Q1 уменьшился всего на 1, медиана на 2, а Q3 на 10. Это говорит об устойчивости межквартильного размаха к выбросам. Что касается быстрых и медленных продаж, то я предлагаю следующий критерий: все, что меньше Q1 (<44) - быстрые; все, что больше Q3 (>222) - медленные. А то, что в пределах размаха - продажи средней длительности.</span>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h3> Комментарий ревьюера ❌<a class="tocSkip"></h3>
#
# Вывод верный. Но стоит проверить, какой объём данных потеряли, потому что если выбросов больше 10 %, то это уже не выбросы, а часть тренда.
# </div>

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера v2 ✔️<a class="tocSkip"> </h3>
#
#  👍
# </div>

# %% [markdown]
# ### <span style="color:orange">Подшаг 4.3. Факторы, влияющие на стоимость объекта.</span>

# %%
pd.plotting.scatter_matrix(data[['last_price', 'total_area', 'living_area', 'kitchen_area']], figsize=(12, 12))
display(data[['last_price', 'total_area', 'living_area', 'kitchen_area']].corr().round(2))
# Out:
#               last_price  total_area  living_area  kitchen_area
# last_price          1.00        0.78         0.63          0.59
# total_area          0.78        1.00         0.90          0.56
# living_area         0.63        0.90         1.00          0.32
# kitchen_area        0.59        0.56         0.32          1.00

# %% [markdown]
# #### <span style="color:brown">Ячейка last_price-total_area: связь стоимости и общей площади. До 100 кв., стоимость и общая площадь увеличиваются равномерно, а после — идут вразнобой.</span>
# #### <span style="color:brown">Ячейка last_price-living_area: связь стоимости и жилой площади. До 60 кв.м., стоимость и жилая площадь тесно связаны, а затем зависимость перестаёт быть устойчивой.</span>
# #### <span style="color:brown">Ячейка last_price-kitchen_area: связь стоимости и кухонной площади. До 15 кв.м., стоимость и площадь кухни тесно связаны, а после - идут вразнобой.</span>

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера v2 ✔️<a class="tocSkip"> </h3>
#
#  Абсолютно верно
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h3> Комментарий ревьюера ❌<a class="tocSkip"></h3>
#
# Для отображения связи между параметрами выше, можно воспользоваться корреляциями с помощью функции corr() и графиками scatterplot или по-другому диаграммами рассеяния. Добавь, пожалуйста решение.
#
# По столбцам ниже график выбран верно, так как корреляция Пирсона и scatterplot для них непоказательны.
# </div>

# %%
ay = data.pivot_table(index='rooms', values='price_square').plot(grid=True, kind='bar', figsize=(12, 8))

# делаем шкалу с шагом в 4000 руб.
min_, max_ = 0.0, 168000.0
step_ = 4000

# получаем сетку от 0 до 168000 с шагом 4000
ticks = np.arange(min_, max_, step_)

# добавляем шкалу на график
ay.set_yticks(ticks)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ####  <span style="color:brown">Комментарий к графику: стоимость квадратного метра у однокомнатных этажей выше, чем у 2-х и 3-х комнатных. Начиная с 4 этажа, стоимость квдаратного метра увеличивается по мере увеличения количества комнат.</span>

# %%
data.pivot_table(index='type_floor', values='price_square').plot(grid=True, kind='bar', figsize=(12, 8))
# Out:
# <AxesSubplot:xlabel='type_floor'>

# %% [markdown]
# ####  <span style="color:brown">Комментарий к графику: Согласно графику, первые этажи имеют самую низкую стоимость за квадратный метр. Чуть лучше идут дела у последних этажей. Но самая высокая стоимость у промежуточных этажей.</span>

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера ✔️<a class="tocSkip"> </h3>
#
#  По этажам и количеству комнат всё верно
# </div>

# %%
data.pivot_table(index='weekday', values='price_square').plot(grid=True, kind='bar', figsize=(12, 8))
# Out:
# <AxesSubplot:xlabel='weekday'>

# %% [markdown]
# ####  <span style="color:brown">Комментарий к графику: Цена не зависит от дня публикации.</span>

# %%
data.pivot_table(index='month', values='price_square').plot(grid=True, kind='bar', figsize=(12, 8))
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# ####  <span style="color:brown">Комментарий к графику: Цена не зависит от месяца публикации.</span>

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера ✔️<a class="tocSkip"> </h3>
#
#  Да, от дня и месяца цена не зависит.
# </div>

# %%
data.pivot_table(index='year', values='price_square').plot(grid=True, kind='bar', figsize=(12, 8))
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# ####  <span style="color:brown">Комментарий к графику: В 2014 году были самые высокие цены на жилье. Потом они начали активно падать. Видимо, это связано с геополитическими процессами, которые произошли в 2014 году. Особой пользы от этой информации нет.
# </span>

# %% [markdown]
# <div class="alert alert-success">
# <h3> Комментарий ревьюера ✔️<a class="tocSkip"> </h3>
#
#  Верно
# </div>

# %% [markdown]
# ### <span style="color:orange">Подшаг 4.4. Средняя цена квадратного метра.</span>

# %% [markdown]
# #### Определяем 10 населенных пунктов с наибольшим числом объявлений:

# %%
price_stats = data.pivot_table(index='locality_name', values='price_square').round()

price_stats['counts'] = data['locality_name'].value_counts()

display(price_stats.sort_values(by='counts', ascending=False).head(10))
# Out:
#                    price_square  counts
# locality_name
# Санкт-Петербург        114849.0   15721
# Мурино                  86088.0     590
# поселок Шушары          78677.0     440
# Всеволожск              68654.0     398
# Пушкин                 103126.0     369
# Колпино                 75425.0     338
# поселок Парголово       90176.0     327
# Гатчина                 68746.0     307
# деревня Кудрово         92474.0     299
# Выборг                  58142.0     237

# %%
# строим таблицу для наглядности
price_stats.query('counts >= 237').plot(grid=True, kind='bar', figsize=(12, 8))
# Out:
# <AxesSubplot:xlabel='locality_name'>

# %% [markdown]
# #### <span style="color:brown">Комментарий к таблице: Санкт-Петербург одновременно является самым распространенным регионом среди объявлений и обладателем самой высокой средней стоимости квадратного метра: 114849 руб. Замыкает ТОП-10 город Выборг. Он упоминается 237 раз, а средняя стоимость квадратного метра жилья составляет 58142 руб.</span>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h3> Комментарий ревьюера ❌<a class="tocSkip"></h3>
#
# Верный вывод. Для наглядного отображения результатов построй, пожалуйста, барплот по этой таблице
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h3> Комментарий ревьюера v2 ⚠️<a class="tocSkip"> </h3>
#
# Супер, данные наглядно отображены. Но стоило бы отсортировать таблицу по увеличению цены
#
# </div>

# %% [markdown]
# ### <span style="color:orange">Подшаг 4.5. Зависимость цены и удаленности от центра.</span>

# %% [markdown]
# #### Делаем срез по питерским объявлениям и сохраняем его в новую переменную

# %%
piter_loc = data.query('locality_name == "Санкт-Петербург"')

# %% [markdown]
# #### Строим график по сводной таблице

# %%
ax = piter_loc.pivot_table(index='km_centre', values='last_price').plot(grid=True, figsize=(20, 10))

# делаем шкалу с шагом в 1км
min_km, max_km = 0.0, 30.0
step_km = 1

# получаем сетку от 0 до 30 с шагом 1
ticks = np.arange(min_km, max_km, step_km)

# добавляем шкалу на график
ax.set_xticks(ticks)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### <span style="color:brown">По графику мы наблюдаем, что чем дальше от центра, тем ниже стоимость квартир (с небольшими колебаниями). Однако в конце графика мы наблюдаем аномалию: между 26-м и 27-м километрами от центра происходит резкий скачок цен, а затем такой же резкий возврат к прежнему состоянию. Интересно, чем примечателен этот промежуток? Давайте рассмотрим этот участок датасета отдельно.</span>

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера v2 ✔️<a class="tocSkip"> </h3>
#
#  Да, вывод верный
# </div>

# %%
m = data.query('25.5 <= km_centre <= 28.4' )

n = m[['locality_name', 'last_price', 'price_square', 'total_area', 'living_area', 'kitchen_area', 'rooms', 'airports_nearest', 'cityCenters_nearest', 'parks_around3000', 'ponds_around3000']]

display(n.sort_values(by='last_price', ascending=False).head(20))
# Out:
#                  locality_name  last_price  price_square  total_area  \
# 19852                   Пушкин  24800000.0     204451.77      121.30
# 18386                   Пушкин  24800000.0     130526.32      190.00
# 2003              Красное Село  21000000.0      97674.42         NaN
# 140                     Пушкин  16912000.0     160000.00      105.70
# 7996                    Пушкин  16600000.0     156603.77      106.00
# 12526                   Пушкин  16500000.0     109271.52      151.00
# 15578                   Пушкин  16000000.0     157016.68      101.90
# 12466                   Пушкин  15000000.0     167410.71       89.60
# 2023                    Пушкин  14700000.0     130088.50      113.00
# 11499                   Пушкин  14500000.0     148261.76       97.80
# 748            Санкт-Петербург  14350000.0     193918.92       74.00
# 670    поселок Александровская  13700000.0      76966.29      178.00
# 21091                   Пушкин  13300000.0     103906.25      128.00
# ...

# %% [markdown]
# #### <span style="color:brown">Сразу бросается в глаза, что большинство квартир расположены в городе Пушкин. Давайте проверим какое количество они составляют от общего числа квартир этого среза. </span>

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера v2 ✔️<a class="tocSkip"> </h3>
#
#  Квартир небольшое количество
# </div>

# %%
x_pushkin = len(m)
y_pushkin = len(m.query('locality_name == "Пушкин"'))
w_pushkin = y_pushkin / x_pushkin * 100

display(w_pushkin)
# Out:
# 46.98795180722892

# %% [markdown]
# #### <span style="color:brown">Почти половина квартир в cрезе находятся в городе Пушкин. Стоит взять это во внимание. Давайте теперь графически рассмотрим, что же такого в Пушкине на расстоянии 25,5 - 27,4 км от центра Петербурга. </span>

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202024-04-28%20%D0%B2%2012.40.33.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202024-04-28%20%D0%B2%2012.40.33.png)

# %% [markdown]
# #### <span style="color:brown">Вот и вывод. Как раз на этом расстоянии от центра Питера находится и центр самого города Пушкин, в котором находятся такие культурно-исторические объекты как Екатерининский и Александровский дворец, а также Царское село. Соответственно, и цены на жилье в этом районе выше остальных. Так как расстояние до центра считаеся автоматически, то спутник привязывается к центру Питера. Однако пользователь, который указывает стоимость жилья, привязывается к центру города Пушкин. И из-за этого происходит расхождение между расстоянием до центра и стоимостью жилья. Думаю, что аномалия на графике объяснена.  </span>

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера v2 ✔️<a class="tocSkip"> </h3>
#
#  Круто, что дополнил решение внешней информацией. Это очень хороший подход
# </div>

# %% [markdown]
# ### <span style="color:brown">Комментарии к шагу 4:</span>
# #### <span style="color:brown">- Самая популярная общая площадь - в районе 45 кв.м.</span>
# #### <span style="color:brown">- Самая популярная жилая площадь - в районе 30 кв.м.</span>
# #### <span style="color:brown">- Самая популярная кухонная площадь - в районе 8-10 кв.м.</span>
# #### <span style="color:brown">- Самая популярная цена - в районе 3,5-4,5 млн.руб.</span>
# #### <span style="color:brown">- Самое популярное число комнат: 1-2 комнаты.</span>
# #### <span style="color:brown">- Самое популярное расстояние до центра 15 км.</span>
# #### <span style="color:brown">- Самое популярное расстояние до парка 400-500м.</span>
# #### <span style="color:brown">- Самая популярная высота потолка 2,5 м.</span>
# #### <span style="color:brown">- Самая популярная этажность дома - 5 и 9 этажей.</span>
#
# #### <span style="color:brown">Средняя продолжительность продажи квартиры – 167 дней.</span>
# #### <span style="color:brown">Медианная продолжительность продажи – 93 дня.</span>
# #### <span style="color:brown">Все, что меньше Q1 (44 дней) - быстрые; все, что больше Q3 (222 дней) - медленные. А то, что в пределах межквартильного размаха - продажи средней длительности.</span>
#
# #### <span style="color:brown">Цена не зависит от дня недели, месяца или года публикации.</span>
# #### <span style="color:brown">Стоимость квадратного метра у однокомнатных этажей выше, чем у 2-х и 3-х комнатных. Начиная с 4 этажа, стоимость квдаратного метра увеличивается по мере увеличения количества комнат.</span>
# #### <span style="color:brown">До 100 кв.м. стоимость и общая площадь увеличиваются равномерно, а после — идут вразнобой.</span>
# #### <span style="color:brown">До 60 кв.м. стоимость и жилая площадь тесно связаны, а затем зависимость перестаёт быть устойчивой.</span>
# #### <span style="color:brown">До 15 кв.м. стоимость и площадь кухни тесно связаны, а после - идут вразнобой.</span>
#
# #### <span style="color:brown">Чем ближе к центру, тем выше стоимость квартир.</span>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h3> Комментарий ревьюера ❌<a class="tocSkip"></h3>
#
# И какой вывод по таблице?
# </div>

# %% [markdown]
#  <div class="alert alert-success">
# <h3> Комментарий ревьюера v2✔️<a class="tocSkip"> </h3>
#
#  👍
# </div>

# %% [markdown]
# ### Напишите общий вывод

# %% [markdown]
# <div class="alert alert-danger">
#     <h3> Комментарий ревьюера ❌<a class="tocSkip"> </h3>
#
# Вывод - важный этап работы, без которого весь твой труд может остаться незамеченным.
#
# Стоит учитывать, что твой потенциальный руководитель, в первую очередь, обратит внимание на общий вывод. Поэтому важно отразить в нём все основные результаты из всех шагов проекта в числах. И важно описать проблемы, найденные на этапе предобработки, и пути их решения
#
# Можно опираться на такую структуру финального вывода во всех проектах:
# * предобработка данных с описанием найденных проблем и путей их решения
# * ответы на цели проекта
# * рекомендации для заказчика
#
# Чтобы лучше понимать, как оформлять комментарии в markdown-ячейках, советую изучить [краткое руководство по Маркдауну](https://paulradzkov.com/2014/markdown_cheatsheet/).
#
# </div>

# %% [markdown]
# ## Предобработка данных и устранение найденных проблем
#
# ### В ходе ознакомления с базой данных были выявлены и устранены следующие недоработки:
#  - Пустые значения. Там, где это возможно, пустые значения были заменены на числовые.
#  - Неявные дубликаты. Например, "поселок Мурино" и "посёлок Мурино" из-за одной буквы считывались как два разных населенных пункта.
#  - Аномальные значения. Например, ноль комнат в квартирах, высота потолков в 20 м. Или же где жилая площадь больше общей площади.
#  - Стоимость в разных категориях. Например, в большинстве случаев указано цена за квартиру, но где-то указана цена не за квартиру, а за квадратный метр.

# %% [markdown]
# ## Цель проекта
#
# ### В ходе проведения исследовательского анализа были сделаны следующие выводы:

# %% [markdown]
# - Рыночная стоимость жилья выводится из общей площади квартиры: в среднем, это 140 тыс. на 1 кв.м. общего жилья. Однако такая корреляция имеет место быть при условии, что площадь квартиры не превышает 100 кв.м. Если квартира имеет более 100 кв.м., то корреляция не такая очевидная.
# - Подобная корреляция есть и для жилой площади: это 170 тыс. на 1 кв.м. жилой площади. Однако и здесь есть ограничение: подобная взаимосвязь существует лишь для квартир, чья жилая площадь не превышает 60 кв.м. При большей жилой площади, взаимосвязь нестабильна.
# - Самые дорогие квадраты приходятся на площадь кухни: это 800 тыс. на 1 кв.м. Но при условии, что кухня не больше 15 кв.м. Для квартир с более просторными кухнями, такая корреляция не так очевидна.
# - Зависимость стоимости 1 кв.м. от количества комнат определена в следующем порядке:
#     - 96 тыс.руб. для 2-х комнатной квартиры;
#     - 98 тыс.руб. для 3-х комнатной квартиры;
#     - 102 тыс.руб. для 1-но комнатной квартиры;
#     - 110 тыс.руб. для 4-х комнатной квартиры;
#     - 127 тыс.руб. для 5-ти комнатной квартиры;
#     - 140 тыс.руб. для 6-ти комнатной квартиры;
#     - 164 тыс.руб. для 7-ми комнатной квартиры.
# - Касательно расстояния до центра. Если рассмотреть график глобально, то чем ближе к центру, то выше цена. Однако, на локальных участках имеются колебания, которые не вписываются в эту тенденцию. Возможно, что квартиры расположены чуть дальше от центра, но ближе к станции метро, и из-за этого их цена выше своих сотоварищей, которые чуть ближе к центру. Нужно больше данных, чтобы вывести более конкретную информацию по этой характеристике.

# %% [markdown]
# ## Рекомендации заказчику:

# %% [markdown]
#  - Столбец "расстояние до центра" необходимо разделить на два столбца. В одном столбце нужно указать расстояние до регионального центра (центр Санкт-Петербурга), а во втором - расстояние до местного центра. Например, в ходе исследования было выявлено, что для квартир в городе Пушкин указано расстояние до центра Петербурга, но пользователи при выставлении цены еще ориентируются и на местный центр. Стоило бы указать две характеристики.
#  - Столбец с указанием расстояния до станции метро. Его нет. Тоже определяющий фактор.
#  - Столбец с указанием квадратуры ванны и санузла. Также будет полезна информация о том, является ли санузел раздельным или совмещенным.
#  - Год постройки дома.
#  - Является ли дом панельным, кирпичным или железобетонным.
#  - Сделать обязательными для заполнения такие пункты как жилая площадь и площадь кухни. Среди этих важных критериев много пропусков, что искажает итоговые выводы. В отличие от балкона, жилая комната и кухня должны быть в квартире обязательно.

# %% [markdown]
# <div class="alert alert-success">
# <h3> Комментарий ревьюера v2 ✔️<a class="tocSkip"> </h3>
#
# Теперь получился очень хороший структурированный вывод. Все этапы проекта и исследовательской части рассмотрены. И даны рекомендации для заказчика. Отличная работа!
#
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Файл с данными открыт.
# - [x]  Файл с данными изучен: выведены первые строки, использован метод `info()`, построены гистограммы.
# - [ ]  Найдены пропущенные значения.
# - [ ]  Пропущенные значения заполнены там, где это возможно.
# - [ ]  Объяснено, какие пропущенные значения обнаружены.
# - [ ]  В каждом столбце установлен корректный тип данных.
# - [ ]  Объяснено, в каких столбцах изменён тип данных и почему.
# - [ ]  Устранены неявные дубликаты в названиях населённых пунктов.
# - [ ]  Обработаны редкие и выбивающиеся значения (аномалии).
# - [ ]  В таблицу добавлены новые параметры:
#        – цена одного квадратного метра;
#        – день публикации объявления (0 - понедельник, 1 - вторник и т. д.);
#        – месяц публикации объявления;
#        – год публикации объявления;
#        – тип этажа квартиры (значения — «первый», «последний», «другой»);
#        – расстояние до центра города в километрах.
# - [ ]  Изучены и описаны параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего парка.
# - [ ]  Выполнено задание «Изучите, как быстро продавались квартиры (столбец `days_exposition`)»:
#     - построена гистограмма;
#     - рассчитаны среднее и медиана;
#     - описано, сколько обычно занимает продажа и указано, какие продажи можно считать быстрыми, а какие — необычно долгими.
# - [ ]  Выполнено задание «Определите факторы, которые больше всего влияют на общую (полную) стоимость объекта». Построены графики, которые показывают зависимость цены от параметров:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - количество комнат;
#         - тип этажа, на котором расположена квартира (первый, последний, другой);
#         - дата размещения (день недели, месяц, год).
# - [ ]  Выполнено задание «Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений»:
#     - выделены населённые пункты с самой высокой и низкой стоимостью квадратного метра.
# - [ ]  Выполнено задание «Выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите их среднюю стоимость на разном удалении от центра»:
#     -  учтён каждый километр расстояния, известны средние цены квартир в одном километре от центра, в двух и так далее;
#     -  описано, как стоимость объекта зависит от расстояния до центра города;
#     -  построен график изменения средней цены для каждого километра от центра Петербурга.
# - [ ]  На каждом этапе сделаны промежуточные выводы.
# - [ ]  В конце проекта сделан общий вывод.
